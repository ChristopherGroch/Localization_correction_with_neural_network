# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

from torch.utils.data import Dataset, DataLoader

# %%
device = 'cpu' #'mps' if torch.backends.mps.is_available() else 'cpu'

# %%
def drop_outliers(dataFrame):
    first_x_quartile = dataFrame['data__coordinates__x'].quantile(0.25)
    second_x_quartile = dataFrame['data__coordinates__x'].quantile(0.75)
    x_std = dataFrame['data__coordinates__x'].std()

    first_y_quartile = dataFrame['data__coordinates__y'].quantile(0.25)
    second_y_quartile = dataFrame['data__coordinates__y'].quantile(0.75)
    y_std = dataFrame['data__coordinates__y'].std()

    dropped_df = dataFrame[(dataFrame['data__coordinates__x'] < (second_x_quartile + 1.5 * x_std)) & (dataFrame['data__coordinates__x'] > (first_x_quartile - 1.5 * x_std)) ]
    dropped_df = dropped_df[(dropped_df['data__coordinates__y'] < (second_y_quartile + 1.5 * y_std)) & (dropped_df['data__coordinates__y'] > (first_y_quartile - 1.5 * y_std)) ]
    return dropped_df

# %%
df = pd.read_csv('data/formatted_df_Train_F10.csv')
df2 = pd.read_csv('data/formatted_df_Test_F10.csv')

df = drop_outliers(df)
df2 = drop_outliers(df2)

dfTest = df2.sample(frac=0.9)
dfValid = df2.drop(dfTest.index)

# %%
class Data(Dataset):
    def __init__(self,dataframe):
        x = dataframe.iloc[:,:24].values
        y = dataframe.iloc[:,24:26].values
        self.len = dataframe.shape[0]

        self.x_train = torch.tensor(x,dtype=torch.float32)
        self.y_train = torch.tensor(y,dtype=torch.float32)

    def __getitem__(self, idx):
        return self.x_train[idx], self.y_train[idx]

    def __len__(self):
        return self.len

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.l1 = nn.Linear(24,50)
        self.l2 = nn.Linear(50,30)
        self.l3 = nn.Linear(30,20)
        self.l4 = nn.Linear(20,15)
        self.l5 = nn.Linear(15,10)
        self.l6 = nn.Linear(10,2)
    def forward(self,x):
        y_pred = F.selu(self.l1(x))
        y_pred = F.selu(self.l2(y_pred))
        y_pred = F.selu(self.l3(y_pred))
        y_pred = F.selu(self.l4(y_pred))
        y_pred = F.selu(self.l5(y_pred))
        y_pred = self.l6(y_pred)

        return  y_pred

# %%
model = Model()
model.to(device)
train_dataset = Data(df)
valid_dataset = Data(dfValid)
train_loader = DataLoader(dataset=train_dataset,batch_size=80,shuffle=True)
valid_loader = DataLoader(dataset=valid_dataset,batch_size=200)

# %%
optimizer = torch.optim.Adam(model.parameters(),lr=0.00001)
criterion = nn.MSELoss()

# %%
epochs = 60
min_loss = np.inf

for epoch in range(epochs):
    model.train()
    train_loss = 0.0
    for i,(x,y) in enumerate(train_loader):
        x = x.to(device)
        y = y.to(device)
        y_result = model(x)
        loss = criterion(y_result, y)
        train_loss += loss
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    model.eval()
    valid_loss = 0.0
    with torch.no_grad():
        for x,y in valid_loader:
            x = x.to(device)
            y = y.to(device)
            y_result = model(x)
            loss = criterion(y_result, y)
            valid_loss += loss

    valid_loss /= len(valid_loader)
    train_loss /= len(train_loader)
    print(f"Epoch = {epoch + 1}\tTrain loss = {train_loss}\tValid loss = {valid_loss}")
    if valid_loss < min_loss:
        print(f"Loss decreased by {min_loss - valid_loss}")
        min_loss = valid_loss
        torch.save(model, "testing_training_F10/models/model_test3.pth")
# Out:
# Epoch = 1	Train loss = 11384286.0	Valid loss = 12163215.0
# Loss decreased by inf
# Epoch = 2	Train loss = 11204268.0	Valid loss = 11805380.0
# Loss decreased by 357835.0
# Epoch = 3	Train loss = 10499564.0	Valid loss = 10611601.0
# Loss decreased by 1193779.0
# Epoch = 4	Train loss = 8836623.0	Valid loss = 8319914.0
# Loss decreased by 2291687.0
# Epoch = 5	Train loss = 6149543.5	Valid loss = 5286587.0
# Loss decreased by 3033327.0
# Epoch = 6	Train loss = 3408196.0	Valid loss = 2963476.0
# Loss decreased by 2323111.0
# Epoch = 7	Train loss = 1781934.5	Valid loss = 1881744.75
# Loss decreased by 1081731.25
# Epoch = 8	Train loss = 1139339.25	Valid loss = 1392326.75
# Loss decreased by 489418.0
# Epoch = 9	Train loss = 846871.4375	Valid loss = 1091464.125
# Loss decreased by 300862.625
# Epoch = 10	Train loss = 679373.4375	Valid loss = 895598.1875
# Loss decreased by 195865.9375
# Epoch = 11	Train loss = 586228.5625	Valid loss = 773464.5
# Loss decreased by 122133.6875
# Epoch = 12	Train loss = 540676.5625	Valid loss = 705412.3125
# Loss decreased by 68052.1875
# Epoch = 13	Train loss = 523071.375	Valid loss = 671663.1875
# Loss decreased by 33749.125
# Epoch = 14	Train loss = 518249.9375	Valid loss = 658511.625
# Loss decreased by 13151.5625
# Epoch = 15	Train loss = 516092.3125	Valid loss = 652947.75
# Loss decreased by 5563.875
# Epoch = 16	Train loss = 514742.15625	Valid loss = 650038.25
# Loss decreased by 2909.5
# Epoch = 17	Train loss = 513187.25	Valid loss = 647961.625
# Loss decreased by 2076.625
# Epoch = 18	Train loss = 512463.5625	Valid loss = 645835.5
# Loss decreased by 2126.125
# Epoch = 19	Train loss = 511065.03125	Valid loss = 643873.0625
# Loss decreased by 1962.4375
# Epoch = 20	Train loss = 509766.875	Valid loss = 641210.625
# Loss decreased by 2662.4375
# Epoch = 21	Train loss = 507218.75	Valid loss = 636445.9375
# Loss decreased by 4764.6875
# Epoch = 22	Train loss = 503690.0	Valid loss = 631748.9375
# Loss decreased by 4697.0
# Epoch = 23	Train loss = 497660.96875	Valid loss = 622725.0
# Loss decreased by 9023.9375
# Epoch = 24	Train loss = 487583.0625	Valid loss = 607281.3125
# Loss decreased by 15443.6875
# Epoch = 25	Train loss = 470908.1875	Valid loss = 580831.3125
# Loss decreased by 26450.0
# Epoch = 26	Train loss = 440395.71875	Valid loss = 525398.9375
# Loss decreased by 55432.375
# Epoch = 27	Train loss = 382611.78125	Valid loss = 448517.6875
# Loss decreased by 76881.25
# Epoch = 28	Train loss = 310028.0625	Valid loss = 357578.5625
# Loss decreased by 90939.125
# Epoch = 29	Train loss = 230311.625	Valid loss = 261744.71875
# Loss decreased by 95833.84375
# Epoch = 30	Train loss = 156469.84375	Valid loss = 180754.25
# Loss decreased by 80990.46875
# Epoch = 31	Train loss = 102494.5234375	Valid loss = 128955.4296875
# Loss decreased by 51798.8203125
# Epoch = 32	Train loss = 73838.4609375	Valid loss = 101157.5390625
# Loss decreased by 27797.890625
# Epoch = 33	Train loss = 58165.08984375	Valid loss = 82277.6640625
# Loss decreased by 18879.875
# Epoch = 34	Train loss = 46996.1328125	Valid loss = 67377.9921875
# Loss decreased by 14899.671875
# Epoch = 35	Train loss = 37712.4375	Valid loss = 55857.9921875
# Loss decreased by 11520.0
# Epoch = 36	Train loss = 30960.056640625	Valid loss = 47320.9296875
# Loss decreased by 8537.0625
# Epoch = 37	Train loss = 25937.9140625	Valid loss = 40824.77734375
# Loss decreased by 6496.15234375
# Epoch = 38	Train loss = 21921.193359375	Valid loss = 35988.16796875
# Loss decreased by 4836.609375
# Epoch = 39	Train loss = 18936.865234375	Valid loss = 32401.50390625
# Loss decreased by 3586.6640625
# Epoch = 40	Train loss = 16349.8046875	Valid loss = 29569.404296875
# Loss decreased by 2832.099609375
# Epoch = 41	Train loss = 14397.341796875	Valid loss = 28050.69921875
# Loss decreased by 1518.705078125
# Epoch = 42	Train loss = 13136.48828125	Valid loss = 27067.248046875
# Loss decreased by 983.451171875
# Epoch = 43	Train loss = 12295.4248046875	Valid loss = 26575.736328125
# Loss decreased by 491.51171875
# Epoch = 44	Train loss = 11705.88671875	Valid loss = 26173.32421875
# Loss decreased by 402.412109375
# Epoch = 45	Train loss = 11251.603515625	Valid loss = 26020.14453125
# Loss decreased by 153.1796875
# Epoch = 46	Train loss = 10860.73828125	Valid loss = 25902.794921875
# Loss decreased by 117.349609375
# Epoch = 47	Train loss = 10571.1689453125	Valid loss = 25699.2265625
# Loss decreased by 203.568359375
# Epoch = 48	Train loss = 10322.5078125	Valid loss = 25621.6953125
# Loss decreased by 77.53125
# Epoch = 49	Train loss = 10103.3251953125	Valid loss = 25802.673828125
# Epoch = 50	Train loss = 9921.220703125	Valid loss = 25697.12109375
# Epoch = 51	Train loss = 9753.560546875	Valid loss = 25774.0078125
# Epoch = 52	Train loss = 9613.7978515625	Valid loss = 25839.83984375
# Epoch = 53	Train loss = 9492.3408203125	Valid loss = 25887.30859375
# Epoch = 54	Train loss = 9364.916015625	Valid loss = 25976.63671875
# Epoch = 55	Train loss = 9246.80859375	Valid loss = 26029.888671875
# Epoch = 56	Train loss = 9144.419921875	Valid loss = 26284.296875
# Epoch = 57	Train loss = 9048.6787109375	Valid loss = 26400.8671875
# Epoch = 58	Train loss = 8964.3818359375	Valid loss = 26566.390625
# Epoch = 59	Train loss = 8884.6357421875	Valid loss = 26807.3046875
# Epoch = 60	Train loss = 8817.9873046875	Valid loss = 26665.8828125

# %%
# model = torch.load('testing_training_F10/models/model_test3.pth')

# %%
test_F10 = dfTest.iloc[:,:24].values
test_F10 = torch.tensor(test_F10,dtype=torch.float32,device=device)
test_F10_cords = dfTest.iloc[:,22:24].values
test_F10_cords = torch.tensor(test_F10_cords,dtype=torch.float32,device=device)

# %%
predictions = model(test_F10)
predictions_transposed = torch.transpose(predictions,0,1)
predictions_numpy = predictions_transposed.cpu().data.numpy()

# %%
plt.figure(figsize=(10, 7))
plt.scatter(x=dfTest.data__coordinates__x,y=dfTest.data__coordinates__y,c='r',label="read data")
plt.scatter(x=predictions_numpy[0],y=predictions_numpy[1],c='b',alpha=0.1,label='calculated data')
plt.scatter(x=dfTest.reference__x,y=dfTest.reference__y,c='orange',label='true data')
plt.legend(loc="upper left")
plt.title("Points location")
plt.show()

# %%
test_F10_y = dfTest.iloc[:,24:26].values
test_F10_y = torch.tensor(test_F10_y,dtype=torch.float32,device=device)

# %%
error_without_neural = torch.empty((test_F10_y.size()[0]),dtype=torch.float32,device=device)
error_after_neural = torch.empty((test_F10_y.size()[0]),dtype=torch.float32,device=device)

# %%
for i,to in enumerate(test_F10_y):
    error_without_neural[i] = criterion(to,test_F10_cords[i])
    error_after_neural[i] = criterion(to,predictions[i])

# %%
error_without_neural_out = error_without_neural.cpu().data.numpy()
error_after_neural_out = error_after_neural.cpu().data.numpy()

# %%
error_without_neural_out = (error_without_neural_out * 2)
error_without_neural_out = np.sqrt(error_without_neural_out)
error_after_neural_out = (error_after_neural_out * 2)
error_after_neural_out = np.sqrt(error_after_neural_out)

# %%
help_df_1 = pd.DataFrame(columns=['Error',"After neural network"])
help_df_1['Error'] = error_after_neural_out
help_df_1['After neural network'] = True

# %%
help_df_2 = pd.DataFrame(columns=['Error', "After neural network"])
help_df_2['Error'] = error_without_neural_out
help_df_2['After neural network'] = False

# %%
help_df = pd.concat([help_df_2,help_df_1])

# %%
plt.figure(figsize=(10, 7))
sns.displot(data=help_df,x="Error",kind='ecdf',hue="After neural network")
plt.title('Error distribution')
plt.show()
